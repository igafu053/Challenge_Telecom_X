# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %% [markdown]
# ✅ Cargar los datos directamente desde la API utilizando Python.

# %%
telecomx_data = pd.read_json('/content/drive/MyDrive/Aprendiendo_a_hacer_ETL_G8-ONE/Challenge_Telecom_X-Análisis_de_evasión_de_cliente/Challenge_Telecom_X/TelecomX_Data.json')
telecomx_data.head(5)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
#Verificar las columnas del archivo
columnas = list(telecomx_data.columns)
columnas
# Out:
# ['customerID', 'Churn', 'customer', 'phone', 'internet', 'account']

# %%
#Extraer los datos desde los diccionarios anidados en nuevas columnas
customer = pd.json_normalize(telecomx_data['customer'])
phone = pd.json_normalize(telecomx_data['phone'])
internet = pd.json_normalize(telecomx_data['internet'])
account = pd.json_normalize(telecomx_data['account'])

#Concadenar el nuevo dataframe con el dataframe original (excluyendo las columnas anidadas originales)
datos_telecom = pd.concat([telecomx_data[['customerID', 'Churn']], customer, phone, internet, account], axis=1)

#Mostrar las primeras filas del nuevo dataframe
datos_telecom.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
#Verificar las columnas del archivo normalizado
columnas = list(datos_telecom.columns)
columnas
# Out:
# ['customerID',
#  'Churn',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Charges.Monthly',
#  'Charges.Total']

# %% [markdown]
# ✅ Convertir los datos a un DataFrame de Pandas para facilitar su manipulación.

# %%
datos_telecom = pd.DataFrame(datos_telecom)
datos_telecom.head(5)
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
#Convertir el ID del cliente en el indice del archivo
datos_telecom.set_index('customerID', inplace=True)
datos_telecom
# Out:
#            Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# customerID
# 0002-ORFBO    No  Female              0     Yes        Yes       9
# 0003-MKNFE    No    Male              0      No         No       9
# 0004-TLHLJ   Yes    Male              0      No         No       4
# 0011-IGKFF   Yes    Male              1     Yes         No      13
# 0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...     ...            ...     ...        ...     ...
# 9987-LUTYD    No  Female              0      No         No      13
# 9992-RRAMN   Yes    Male              0     Yes         No      22
# 9992-UJOEL    No    Male              0      No         No       2
# 9993-LHIEB    No    Male              0     Yes        Yes      67
# 9995-HOTOH    No    Male              0     Yes        Yes      63
#
#            PhoneService     MultipleLines InternetService OnlineSecurity  \
# customerID
# ...

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ✅ Explorar las columnas del dataset y verificar sus tipos de datos.

# %%
datos_telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 0002-ORFBO to 9995-HOTOH
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Churn             7267 non-null   object
#  1   gender            7267 non-null   object
#  2   SeniorCitizen     7267 non-null   int64
#  3   Partner           7267 non-null   object
#  4   Dependents        7267 non-null   object
#  5   tenure            7267 non-null   int64
#  6   PhoneService      7267 non-null   object
#  7   MultipleLines     7267 non-null   object
#  8   InternetService   7267 non-null   object
#  9   OnlineSecurity    7267 non-null   object
#  10  OnlineBackup      7267 non-null   object
#  11  DeviceProtection  7267 non-null   object
#  12  TechSupport       7267 non-null   object
#  13  StreamingTV       7267 non-null   object
#  14  StreamingMovies   7267 non-null   object
#  15  Contract          7267 non-null   object
# ...

# %%
datos_telecom.dtypes
# Out:
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %%
import numpy as np

# %%
#Reemplazar espacios en blanco en valores nan y convertir strings en numeros
datos_telecom['Charges.Total'] = datos_telecom['Charges.Total'].replace(' ', np.nan)
datos_telecom['Charges.Total'] = pd.to_numeric(datos_telecom['Charges.Total'], errors='coerce')
datos_telecom.tail()
# Out:
#            Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# customerID
# 9987-LUTYD    No  Female              0      No         No      13
# 9992-RRAMN   Yes    Male              0     Yes         No      22
# 9992-UJOEL    No    Male              0      No         No       2
# 9993-LHIEB    No    Male              0     Yes        Yes      67
# 9995-HOTOH    No    Male              0     Yes        Yes      63
#
#            PhoneService     MultipleLines InternetService OnlineSecurity  \
# customerID
# 9987-LUTYD          Yes                No             DSL            Yes
# 9992-RRAMN          Yes               Yes     Fiber optic             No
# 9992-UJOEL          Yes                No             DSL             No
# 9993-LHIEB          Yes                No             DSL            Yes
# 9995-HOTOH           No  No phone service             DSL            Yes
#
#            OnlineBackup DeviceProtection TechSupport StreamingTV  \
# customerID
# ...

# %%
#Convertir el tipo de datos de la columna 'Charges.Total' en datos float64
datos_telecom['Charges.Total'] = datos_telecom['Charges.Total'].astype(np.float64)
datos_telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 0002-ORFBO to 9995-HOTOH
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Churn             7267 non-null   object
#  1   gender            7267 non-null   object
#  2   SeniorCitizen     7267 non-null   int64
#  3   Partner           7267 non-null   object
#  4   Dependents        7267 non-null   object
#  5   tenure            7267 non-null   int64
#  6   PhoneService      7267 non-null   object
#  7   MultipleLines     7267 non-null   object
#  8   InternetService   7267 non-null   object
#  9   OnlineSecurity    7267 non-null   object
#  10  OnlineBackup      7267 non-null   object
#  11  DeviceProtection  7267 non-null   object
#  12  TechSupport       7267 non-null   object
#  13  StreamingTV       7267 non-null   object
#  14  StreamingMovies   7267 non-null   object
#  15  Contract          7267 non-null   object
# ...

# %%
#Columnas pocos relevantes para el analisis de los datos
columnas_excluidas = ['gender','SeniorCitizen','Partner','Dependents','PaperlessBilling','PaymentMethod']

# %% [markdown]
# ✅ Identificar las columnas más relevantes para el análisis de evasión.

# %%
#Filtrar los datos mas relevantes del archivo para el analisis
datos_telecom_filtrado = datos_telecom.drop(columns=columnas_excluidas)
datos_telecom_filtrado.head()
# Out:
#            Churn  tenure PhoneService MultipleLines InternetService  \
# customerID
# 0002-ORFBO    No       9          Yes            No             DSL
# 0003-MKNFE    No       9          Yes           Yes             DSL
# 0004-TLHLJ   Yes       4          Yes            No     Fiber optic
# 0011-IGKFF   Yes      13          Yes            No     Fiber optic
# 0013-EXCHZ   Yes       3          Yes            No     Fiber optic
#
#            OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# customerID
# 0002-ORFBO             No          Yes               No         Yes
# 0003-MKNFE             No           No               No          No
# 0004-TLHLJ             No           No              Yes          No
# 0011-IGKFF             No          Yes              Yes          No
# 0013-EXCHZ             No           No               No         Yes
#
#            StreamingTV StreamingMovies        Contract  Charges.Monthly  \
# customerID
# ...

# %% [markdown]
# ✅Verificar si hay problemas en los datos

# %%
# Verificar valores ausentes
print("Valores ausentes por columna:")
print(datos_telecom_filtrado.isnull().sum())
# Out:
# Valores ausentes por columna:
# Churn                0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# Charges.Monthly      0
# Charges.Total       11
# dtype: int64

# %%
# prompt: ayudame con codigo para verificar si hay problemas en los datos que puedan afectar el análisis. Presta atención a valores ausentes, duplicados, errores de formato e inconsistencias en las categorías. puedes usar pd.unique() y pd.series.dt.normalize()

import pandas as pd
# Verificar valores ausentes
print("Valores ausentes por columna:")
print(datos_telecom_filtrado.isnull().sum())

# Verificar filas duplicadas
print("\nNúmero de filas duplicadas:", datos_telecom_filtrado.duplicated().sum())

# Verificar valores únicos en columnas categóricas para inconsistencias
print("\nValores únicos en columnas categóricas:")
for col in datos_telecom_filtrado.select_dtypes(include='object').columns:
    print(f"- {col}: {pd.unique(datos_telecom_filtrado[col])}")

# Verificar formatos de fecha si existieran (ejemplo para una columna hipotética 'FechaContrato')
# Si tuvieras una columna de fecha llamada 'FechaContrato'
# try:
#     # Intentar convertir a formato de fecha y normalizar
#     fechas = pd.to_datetime(datos_telecom_filtrado['FechaContrato'], errors='coerce')
#     fechas_normalizadas = fechas.dt.normalize()
#     if fechas.isnull().sum() > 0:
#         print("\nSe encontraron formatos de fecha inconsistentes en 'FechaContrato'.")
#     else:
#         print("\nLos formatos de fecha en 'FechaContrato' parecen consistentes.")
#     # Puedes reemplazar la columna original con las fechas normalizadas si es necesario
#     # datos_telecom_filtrado['FechaContrato'] = fechas_normalizadas
# except KeyError:
#     print("\nLa columna 'FechaContrato' no existe en el DataFrame.")
# except Exception as e:
#     print(f"\nOcurrió un error al procesar la columna de fecha: {e}")


# Verificar la distribución de los valores en columnas numéricas (opcional)
print("\nEstadísticas descriptivas de columnas numéricas:")
print(datos_telecom_filtrado.describe())

# Verificar la distribución de las categorías en columnas categóricas (opcional)
print("\nConteo de valores en columnas categóricas:")
for col in datos_telecom_filtrado.select_dtypes(include='object').columns:
    print(f"\n- {col}:")
    print(datos_telecom_filtrado[col].value_counts())

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
